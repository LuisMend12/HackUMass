# %%
import tensorflow as tf

model = tf.keras.models.load_model('trashnet_mobilenetv2.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]   # dynamic range
tflite_model = converter.convert()

with open('trashnet_model_no_papers.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpaw2qwp6y'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_layer_9')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   135399555248976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135399555249552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135399555252048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135399555251664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135399555250512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135399555251856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135399555250320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135399555250704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135399555251280: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...

# %%
from google.colab import files
files.download('trashnet_model_no_papers.tflite')
